# %% [markdown]
# ![](https://europe-west1-atp-views-tracker.cloudfunctions.net/working-analytics?notebook=tutorials--agent-memory-with-mem0--mem0-tutorial)
#
# # Persistent Memory for AI Agents with Mem0
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NirDiamant/agents-towards-production/blob/main/tutorials/agent-memory-with-mem0/mem0_tutorial.ipynb)

# %% [markdown]
# ## 🎯 Introduction
#
# AI agents suffer from a fundamental limitation: **memory amnesia**. They forget everything after each conversation, can't learn from past interactions, and lose valuable context that could make them truly intelligent assistants.
#
# While basic memory solutions store static information, **[Mem0](https://mem0.dev/github/nir)** introduces a revolutionary approach: **self-improving memory** that automatically extracts insights, resolves conflicts, and evolves with each interaction. Instead of just storing conversations, Mem0 builds an intelligent knowledge system that learns user preferences and provides contextual understanding.

# %% [markdown]
# ## 🛠️ What We'll Build
#
# We'll create an intelligent Personal AI Research Assistant that demonstrates Mem0's full capabilities:
#
# It will:
#
# *   Keep track of your preferences for depth, style, and formatting
# *   Store research notes, summaries, and insights in vector memory for semantic recall
# *   Capture key ideas from your notes and link related concepts inside a graph database
# *   Recognize when new questions relate to earlier discussions and surface the right context
# *   Use both similarity search and structured relationships to generate more informed answers over time
#
# Instead of restarting from zero every session, the assistant continually builds on what it already knows - helping you form a growing, interconnected understanding of the topics you research.

# %% [markdown]
# ## 🏗️ Memory Architecture Overview
#
# **Mem0** is a memory layer for AI agents that automatically extracts important information from conversations, stores it in vector and graph databases, and retrieves it later to provide long-term context and continuity.
#
# Below is the high-level flow illustrating how Mem0 processes and stores memory.
#
# ![mem0_architecture](Assets/mem0_architecture.png)

# %% [markdown]
# ## 🎢 Learning Journey
#
# **Phase 1: Vector Memory Foundation**
#
# *   Basic Assistant: Build a working research assistant with vector memory
# *   Memory Operations: See knowledge extraction and conflict resolution in action
# *   Semantic Search: Experience intelligent retrieval beyond keywords
# *   Self-Improvement: Watch memory evolve with each interaction
#
# **Phase 2: Graph Enhancement**
#
# *   Graph Capabilities: Add entity relationship mapping
# *   Research Networks: Track paper citations, author connections
# *   Knowledge Graphs: Visualize research domain relationships

# %% [markdown]
# ## ⚙️ Prerequisites and Environment Setup
#
# For this tutorial, you'll need:
#
# 1. [OpenAI API Key](https://platform.openai.com/signup) - used for LLM processing (GPT-4) and embeddings
# 2. [Qdrant Cloud Account](https://cloud.qdrant.io) or any other vector store supported by Mem0 for vector memory.
# 3. [Neo4j AuraDB](https://neo4j.com/aura/) or any other graph database supported by Mem0 for Graph Memory

# %% [markdown]
# ### Installation
#
# Let's start by installing all required dependencies:

# %%
# !pip install -q mem0ai openai python-dotenv neo4j
# !pip install langchain-neo4j
# Out:
# Collecting langchain-neo4j
#   Downloading langchain_neo4j-0.8.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-neo4j) (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-neo4j) (1.2.19)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-neo4j) (1.0.2)
# Collecting neo4j-graphrag<2.0.0,>=1.12.0 (from langchain-neo4j)
#   Downloading neo4j_graphrag-1.13.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: neo4j<7.0.0,>=5.25.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-neo4j) (6.1.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (1.0.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (0.4.41)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.11.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.0.40)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (3.10.16)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (0.23.0)
# Requirement already satisfied: anyio in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (4.9.0)
# Requirement already satisfied: certifi in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.0.9)
# Requirement already satisfied: idna in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (3.10)
# Requirement already satisfied: h11>=0.16 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (0.16.0)
# Requirement already satisfied: pytz in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from neo4j<7.0.0,>=5.25.0->langchain-neo4j) (2025.2)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<3.0.0,>=2.1.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j) (2.2.4)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading pypdf-6.9.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting scipy<2.0.0,>=1.15.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting types-pyyaml<7.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.6.3)
# Requirement already satisfied: greenlet>=1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (3.1.1)
# Requirement already satisfied: sniffio>=1.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.3.1)
# Downloading langchain_neo4j-0.8.0-py3-none-any.whl (48 kB)
# Downloading neo4j_graphrag-1.13.1-py3-none-any.whl (222 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading pypdf-6.9.0-py3-none-any.whl (333 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.5/36.5 MB 45.5 kB/s eta 0:13:11
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#     --------------------------------------- 0.8/36.5 MB 68.0 kB/s eta 0:08:46
#    - -------------------------------------- 1.0/36.5 MB 88.7 kB/s eta 0:06:40
#    - -------------------------------------- 1.0/36.5 MB 88.7 kB/s eta 0:06:40
#    - -------------------------------------- 1.0/36.5 MB 88.7 kB/s eta 0:06:40
#    - -------------------------------------- 1.0/36.5 MB 88.7 kB/s eta 0:06:40
#    - -------------------------------------- 1.0/36.5 MB 88.7 kB/s eta 0:06:40
#    - -------------------------------------- 1.3/36.5 MB 104.3 kB/s eta 0:05:38
#    - -------------------------------------- 1.3/36.5 MB 104.3 kB/s eta 0:05:38
#    -------------------------------------- - 35.4/36.5 MB 551.9 kB/s eta 0:00:03
#    ---------------------------------------  35.7/36.5 MB 548.1 kB/s eta 0:00:02
#    ---------------------------------------  35.7/36.5 MB 548.1 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.5 MB 548.5 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.5 MB 548.5 kB/s eta 0:00:02
#    ---------------------------------------  36.2/36.5 MB 551.0 kB/s eta 0:00:01
#    ---------------------------------------  36.2/36.5 MB 551.0 kB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 551.4 kB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 546.1 kB/s  0:01:50
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Installing collected packages: types-pyyaml, scipy, pypdf, json-repair, fsspec, neo4j-graphrag, langchain-neo4j
#
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----- ---------------------------------- 1/7 [scipy]
#    ----------- ---------------------------- 2/7 [pypdf]
#    ----------- ---------------------------- 2/7 [pypdf]
#    ----------------- ---------------------- 3/7 [json-repair]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------- ----------- 5/7 [neo4j-graphrag]
#    ---------------------------------- ----- 6/7 [langchain-neo4j]
#    ---------------------------------------- 7/7 [langchain-neo4j]
#
# Successfully installed fsspec-2024.12.0 json-repair-0.44.1 langchain-neo4j-0.8.0 neo4j-graphrag-1.13.1 pypdf-6.9.0 scipy-1.17.1 types-pyyaml-6.0.12.20250915

# %%
# !pip install rank-bm25
# Out:
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from rank-bm25) (2.2.4)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %%
# !pip install -U qdrant-client
# Out:
# Requirement already satisfied: qdrant-client in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (1.15.1)
# Collecting qdrant-client
#   Downloading qdrant_client-1.17.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: grpcio>=1.41.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (1.76.0)
# Requirement already satisfied: httpx>=0.20.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=2.1.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (2.2.4)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (5.29.5)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (2.11.1)
# Requirement already satisfied: urllib3<3,>=1.26.14 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from qdrant-client) (2.6.3)
# Requirement already satisfied: pywin32>=226 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from portalocker<4.0,>=2.7.0->qdrant-client) (311)
# Requirement already satisfied: typing-extensions~=4.12 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from grpcio>=1.41.0->qdrant-client) (4.15.0)
# Requirement already satisfied: anyio in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.9.0)
# Requirement already satisfied: certifi in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: h11>=0.16 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Downloading qdrant_client-1.17.1-py3-none-any.whl (389 kB)
# Installing collected packages: qdrant-client
#   Attempting uninstall: qdrant-client
#     Found existing installation: qdrant-client 1.15.1
#     Uninstalling qdrant-client-1.15.1:
#       Successfully uninstalled qdrant-client-1.15.1
# Successfully installed qdrant-client-1.17.1

# %% [markdown]
# ### Import Required Libraries

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in D:\PycharmProjects\product_aiagent\.venv\Lib\site-packages (1.1.0)

# %%
# Core libraries
import os
import getpass

# Mem0 and OpenAI
from mem0 import Memory
from openai import OpenAI

# %% [markdown]
# ### Required API Keys
#
# Let's configure your API keys:

# %%
# def setup_api_keys():
#
#     # OpenAI API Key
#     if "OPENAI_API_KEY" not in os.environ:
#         #
#         os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
#
#     # Qdrant Cloud (Required for Phase 1: Vector Memory)
#
#     if "QDRANT_URL" not in os.environ:
#         os.environ["QDRANT_URL"] = input("\nEnter your Qdrant Cloud URL: ")
#     if "QDRANT_API_KEY" not in os.environ:
#         os.environ["QDRANT_API_KEY"] = getpass.getpass("Enter your Qdrant API key: ")
#
#     return True
#
# # Run the setup
# use_qdrant_cloud = setup_api_keys()

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path=".\product_aiagent\.env.development")
def setup_api_key():
    a = os.getenv("OPENAI_API_KEY")
    b = os.getenv("QDRANT_URL")
    c = os.getenv("QDRANT_API_KEY")
    return True
use_qdrant_cloud = setup_api_key()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Trung Truc\AppData\Local\Temp\ipykernel_19816\696666446.py:3: SyntaxWarning: invalid escape sequence '\p'
#   load_dotenv(dotenv_path=".\product_aiagent\.env.development")

# %% [markdown]
# ## Memory Configuration
# ## Phase 1: Vector Memory
#
# Now let's configure Mem0's memory system. We're starting with **vector-based memory** - the foundation that makes everything else possible.
#
#
# ### Understanding the Configuration
#
# Each component serves a specific purpose in the memory pipeline:
#
# - **🤖 LLM Provider**: Extracts insights and resolves conflicts
# - **📊 Embedder**: Converts text into semantic vectors
# - **🗄️ Vector Store**: Stores embeddings for similarity search

# %%
if use_qdrant_cloud:
    # Enhanced configuration with Qdrant Cloud
    config = {
    "llm": {
        "provider": "openai",
        "config": {
            "model": "gpt-4o-mini",
            "temperature": 0.1,
            "max_tokens": 2000,
        }
    },
    "embedder": {
        "provider": "openai",
        "config": {
            "model": "text-embedding-3-large",
            "embedding_dims": 3072,
        }
    },
    "vector_store": {
        "provider": "qdrant",
        "config": {
            "url": os.environ["QDRANT_URL"],
            "api_key": os.environ["QDRANT_API_KEY"],
            "collection_name": "research_assistant_vectors",
            "embedding_model_dims": 3072,  # Must match embedding model
        }
    },
    "version": "v1.1",  # Latest version with enhanced features
}

print("Vector Memory Configuration Created!")
# Out:
# Vector Memory Configuration Created!

# %% [markdown]
# ### Initialize Memory System
#
# Now let's create our memory instance - the brain of our research assistant:

# %%
try:
    memory = Memory.from_config(config)
    print("Memory system initialized successfully!")
except Exception as e:
    print(f"Error initializing memory: {e}")
# Out:
# Memory system initialized successfully!

# %% [markdown]
# ## Building the Research Assistant
#
# Now we'll build our Personal Research Assistant using Mem0's vector memory capabilities.

# %% [markdown]
# ### Core Mem0 Operations
#
# Before we build the assistant, let's understand Mem0's main operations:
#
# `memory.add()` - Stores new information
# - Automatically extracts key facts from conversations
# - Handles deduplication and conflicts
# - Stores memories with user-specific isolation
#
# ![mem0_add_architecture](Assets/mem0_add_architecture.jpg)
#
# `memory.search()` - Retrieves relevant memories
# - Finds semantically similar content (not just keyword matching)
# - Returns ranked results by relevance
# - Supports filtering by user_id
#
# ![mem0_search_architecture](Assets/mem0_search_architecture.jpg)
#
# **Other operations** (not used in this tutorial):
# - `memory.update()` - Modify existing memories
# - `memory.delete()` - Remove specific memories

# %%
class PersonalResearchAssistant:

    def __init__(self, memory_instance):
        self.client = OpenAI()
        self.memory = memory_instance  # Use the configured memory instance
        print(f"Research Assistant initialized with Mem0 memory!")

    def ask(self, question, user_id):


        # Search for relevant memories
        previous_memories = self.search_memories(question, user_id=user_id)

        # Build the prompt with memory context
        system_message = "You are a personal AI Research Assistant. Help users with research questions, remember their interests, and provide contextual recommendations."

        if previous_memories:
            memory_context = ", ".join(previous_memories)
            prompt = f"{system_message}\n\nUser input: {question}\nPrevious memories: {memory_context}"
        else:
            prompt = f"{system_message}\n\nUser input: {question}"

        # Generate response
        try:
            response = self.client.chat.completions.create(
                model="gpt-4o-mini",
                messages=[
                    {"role": "system", "content": prompt},
                ],
                temperature=0.1,
                max_tokens=2000
            )

            answer = response.choices[0].message.content

            # Store the question in memory
            self.memory.add(question, user_id=user_id, metadata={"category": "research"})

            return answer

        except Exception as e:
            return f"Encountered an error: {e}"

    def get_memories(self, user_id):
        try:
            memories = self.memory.get_all(user_id=user_id)
            if isinstance(memories, dict) and 'results' in memories:
                return [m['memory'] for m in memories['results']]
            elif isinstance(memories, list):
                return [m['memory'] for m in memories]
            return []
        except Exception as e:
            print(f"Error retrieving memories: {e}")
            return []

    def search_memories(self, query, user_id):
        try:
            memories = self.memory.search(query, user_id=user_id)
            if isinstance(memories, dict) and 'results' in memories:
                return [m['memory'] for m in memories['results']]
            elif isinstance(memories, list):
                return [m['memory'] for m in memories]
            return []
        except Exception as e:
            print(f"Error searching memories: {e}")
            return []

# Initialize our research assistant
assistant = PersonalResearchAssistant(memory)
print("\n Research Assistant ready to learn and help!")
# Out:
# Research Assistant initialized with Mem0 memory!
#
#  Research Assistant ready to learn and help!

# %% [markdown]
# ### Test 1: First Interaction - Knowledge Extraction
#
# Let's start with a basic research interest:

# %%
response1 = assistant.ask(
    "I'm interested in transformer architectures for natural language processing. "
    "Can you help me find recent papers on this topic?",
    user_id="researcher"
)

print(f"Assistant: {response1}")

# %% [markdown]
# ### Test 2: Building Context - Watch Memory Connect Ideas

# %%
response2 = assistant.ask(
    "I prefer papers that include practical implementation details and code examples. "
    "Theoretical papers without code are less useful for my work.",
    user_id="researcher"
)

print(f"Assistant: {response2}")

# %% [markdown]
# ### Test 3: Semantic Search - Intelligence Beyond Keywords

# %%
response3 = assistant.ask(
    "What about BERT and GPT models? Are they related to my research interests?",
    user_id="researcher"
)

print(f"Assistant: {response3}")

# %% [markdown]
# ### Test 4: Conflict Resolution - Intelligent Memory Management

# %%
response4 = assistant.ask(
    "Actually, I also need to understand the theoretical foundations of attention mechanisms. "
    "Can you recommend some foundational theory papers?",
    user_id="researcher"
)

print(f"Assistant: {response4}")
# Out:
# Assistant: Certainly! Here are some foundational papers on attention mechanisms that you might find helpful:
#
# 1. **"Attention Is All You Need" by Vaswani et al. (2017)** - This is the seminal paper that introduced the Transformer model, which relies heavily on self-attention mechanisms. It provides a comprehensive overview of how attention works in the context of sequence-to-sequence tasks.
#
# 2. **"Neural Machine Translation by Jointly Learning to Align and Translate" by Bahdanau et al. (2014)** - This paper presents the attention mechanism in the context of neural machine translation, introducing the concept of alignment scores and how they can be used to focus on different parts of the input sequence.
#
# 3. **"Show, Attend and Tell: Neural Image Caption Generation with Visual Attention" by Xu et al. (2015)** - This paper extends the attention mechanism to the domain of image captioning, demonstrating how attention can be applied to visual data.
#
# 4. **"Hierarchical Attention Networks for Document Classification" by Yang et al. (2016)** - This paper introduces a hierarchical attention mechanism for document classification, providing insights into how attention can be structured at different levels (word and sentence).
#
# 5. **"Attention-based Models for Speech Recognition" by Chan et al. (2016)** - This paper discusses the application of attention mechanisms in speech recognition, highlighting the versatility of attention across different modalities.
#
# These papers should give you a solid theoretical foundation on attention mechanisms and their applications. If you have any specific areas of interest or applications in mind, let me know, and I can provide more tailored recommendations!

# %% [markdown]
# ## 📊 Memory Analysis - See What Was Learned
#
# Let's examine what our assistant learned from these interactions:

# %%
def analyze_extracted_memories():

    print("📈 MEMORY ANALYSIS - What Did the Assistant Learn?")
    print("=" * 60)

    # Get all memories
    all_memories = assistant.get_memories(user_id="researcher")

    if all_memories:
        print(f"\n🧠 Total memories extracted: {len(all_memories)}")
        print(f"\n📚 Key insights Mem0 learned about you:")

        for i, memory in enumerate(all_memories, 1):
            print(f"\n{i}. {memory}")

        # Test semantic search
        print(f"\n🔍 Testing Semantic Search Capabilities:")

        test_queries = [
            "neural networks",           # Should connect to transformers
            "code implementations",      # Should find practical preferences
            "attention mechanisms",      # Should connect to transformer interest
            "deep learning papers"       # Should find research interests
        ]

        for query in test_queries:
            related_memories = assistant.search_memories(query, user_id="researcher")
            print(f"\n   🔎 Query: '{query}'")
            print(f"      Found {len(related_memories)} related memories")
            if related_memories:
                print(f"      Top match: {related_memories[0][:100]}...")

    else:
        print("\n⚠️ No memories found. Try running the interaction tests first.")

    return all_memories

# Run the analysis
memories = analyze_extracted_memories()
# Out:
# 📈 MEMORY ANALYSIS - What Did the Assistant Learn?
# ============================================================
#
# 🧠 Total memories extracted: 1
#
# 📚 Key insights Mem0 learned about you:
#
# 1. Needs to understand the theoretical foundations of attention mechanisms
#
# 🔍 Testing Semantic Search Capabilities:
#
#    🔎 Query: 'neural networks'
#       Found 1 related memories
#       Top match: Needs to understand the theoretical foundations of attention mechanisms...
#
#    🔎 Query: 'code implementations'
#       Found 1 related memories
#       Top match: Needs to understand the theoretical foundations of attention mechanisms...
#
#    🔎 Query: 'attention mechanisms'
#       Found 1 related memories
#       Top match: Needs to understand the theoretical foundations of attention mechanisms...
#
#    🔎 Query: 'deep learning papers'
#       Found 1 related memories
#       Top match: Needs to understand the theoretical foundations of attention mechanisms...

# %% [markdown]
# ## Interactive Demo - Try It Yourself
#
# Now it's your turn! Try asking questions and watch the memory system learn about your research interests:

# %%
def interactive_demo():
    while True:
        try:
            question = input("\nYou: ")

            if question.lower() in ['quit', 'exit', 'q']:
                print("\n Thanks for trying the Research Assistant!")
                break
            elif question.lower() == 'memories':
                memories = assistant.get_memories(user_id="researcher")
                if memories:
                    print(f"\n Here's what I've learned about your research interests:")
                    for i, memory in enumerate(memories, 1):
                        print(f"   {i}. {memory}")
                else:
                    print("\n No memories yet. Start asking about your research interests!")
            elif question.strip():
                response = assistant.ask(question)
                print(f"\n Assistant: {response}")

        except KeyboardInterrupt:
            print("\n\n Demo ended. Thanks for trying the Research Assistant!")
            break
        except Exception as e:
            print(f"\n Error: {e}")

# Run the interactive demo
interactive_demo()
# Out:
#  Error: PersonalResearchAssistant.ask() missing 1 required positional argument: 'user_id'
#
#
#  Demo ended. Thanks for trying the Research Assistant!

# %% [markdown]
# ## 🚀 Phase 2: Enhancing with Graph Memory Capabilities
#
# Now that you've mastered **vector-based memory** and seen its power, let's enhance our system with **graph capabilities**. This addition will enable explicit relationship mapping between entities, concepts, and research domains.
#
# ### Why Add Graph Memory?
#
# **Vector memory excels at**:
#
# - Finding semantically similar content
# - "Show me papers like this one"
# - Understanding conceptual similarity
#
# **Graph memory adds**:
#
# - Explicit entity relationships
# - "Who collaborated with whom?"
# - "How did Paper A influence Paper B?"
# - Research lineage and citation networks

# %% [markdown]
# ### Graph Storage Setup
#
# To add graph capabilities, we need a graph database. Neo4j is the most popular choice, you can use other graph storage as well that are supported by Mem0.

# %%
# def setup_graph_capabilities():
#
#     print("\n🔗 Enter your Neo4j connection details:")
#     neo4j_uri = input("Neo4j URI (e.g., neo4j+s://xxx.databases.neo4j.io): ")
#     neo4j_username = input("Username (usually 'neo4j'): ")
#     neo4j_password = getpass.getpass("Password: ")
#
#     print("\n Neo4j configuration complete!")
#
#     return True, {
#         "url": neo4j_uri,
#         "username": neo4j_username,
#         "password": neo4j_password
#     }
#
# # Setup graph capabilities for Phase 2
# has_graph, graph_config = setup_graph_capabilities()
# Out:
# 🔗 Enter your Neo4j connection details:
#
#  Neo4j configuration complete!

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path="D:/PycharmProjects/product_aiagent/.env.development")

graph_config = {
        "url": os.getenv("NEO4J_URI"),
        "username": os.getenv("NEO4J_USERNAME"),
        "password": os.getenv("NEO4J_PASSWORD"),
}

# %% [markdown]
# ### Enhanced Configuration with Graph Storage
#
# Now let's create the hybrid configuration with both vector and graph storage:

# %%
# Enhanced configuration with both vector and graph storage
enhanced_config = {
    "llm": {
        "provider": "openai",
        "config": {
            "model": "gpt-4o-mini",
            "temperature": 0.1,
            "max_tokens": 2000,
        }
    },
    "embedder": {
        "provider": "openai",
        "config": {
            "model": "text-embedding-3-large",
            "embedding_dims": 3072,
        }
    },
    "vector_store": {
        "provider": "qdrant",
        "config": {
            "url": os.environ["QDRANT_URL"],
            "api_key": os.environ["QDRANT_API_KEY"],
            "collection_name": "research_assistant_hybrid",
            "embedding_model_dims": 3072,
        }
    },
    "graph_store": {
        "provider": "neo4j",
        "config": graph_config
    },
    "version": "v1.1",
}

try:
    enhanced_memory = Memory.from_config(enhanced_config)
    print("\n Hybrid Memory System Initialized Successfully!")

    enhanced_assistant = PersonalResearchAssistant(enhanced_memory)
    print("\n Enhanced Research Assistant ready with hybrid memory!")

except Exception as e:
    print(f" Error initializing hybrid memory: {e}")

    # Fallback to vector-only
    print("\n Falling back to vector-only assistant...")
    enhanced_assistant = assistant
# Out:
#  Hybrid Memory System Initialized Successfully!
# Research Assistant initialized with Mem0 memory!
#
#  Enhanced Research Assistant ready with hybrid memory!

# %% [markdown]
# ### 📝 Graph-Enhanced Research Examples
#
# If you have graph storage enabled, let's see it in action with entity relationships:

# %% [markdown]
# ### Example 1: Research lineage mapping

# %%
graph_response1 = enhanced_assistant.ask(
    "I'm studying the lineage of transformer papers. The original 'Attention Is All You Need' "
    "by Vaswani et al. led to BERT by Devlin et al., and then to many other models. "
    "Can you help me map these research connections and suggest related work?",
    user_id="graph_user"
)

print(f"Hybrid Assistant: {graph_response1}")
# Out:
# Hybrid Assistant: Absolutely! The lineage of transformer papers is quite fascinating and has led to a plethora of advancements in natural language processing. Here’s a brief mapping of key papers and their connections following the original "Attention Is All You Need" paper:
#
# 1. **Attention Is All You Need** (Vaswani et al., 2017)
#    - This foundational paper introduced the transformer architecture, which relies entirely on self-attention mechanisms.
#
# 2. **BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding** (Devlin et al., 2018)
#    - BERT builds on the transformer architecture by introducing bidirectional training of transformers, which allows the model to consider context from both directions.
#
# 3. **GPT (Generative Pre-trained Transformer)** (Radford et al., 2018)
#    - This model focuses on unsupervised learning and generative tasks, using a unidirectional transformer architecture.
#
# 4. **RoBERTa: A Robustly Optimized BERT Pretraining Approach** (Liu et al., 2019)
#    - RoBERTa modifies BERT's training methodology, using more data and longer training times to improve performance.
#
# 5. **ALBERT: A Lite BERT for Self-supervised Learning of Language Representations** (Lan et al., 2019)
#    - ALBERT reduces the model size of BERT while maintaining performance through parameter sharing and factorized embedding parameterization.
#
# 6. **T5: Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer** (Raffel et al., 2019)
#    - T5 frames all NLP tasks as text-to-text tasks, leveraging the transformer architecture for a wide range of applications.
#
# 7. **XLNet: Generalized Autoregressive Pretraining for Language Understanding** (Yang et al., 2019)
#    - XLNet combines ideas from BERT and autoregressive models, capturing bidirectional context while maintaining the autoregressive nature.
#
# 8. **DistilBERT: A Distilled Version of BERT** (Sanh et al., 2019)
#    - DistilBERT is a smaller, faster, and lighter version of BERT, designed to retain most of its performance while being more efficient.
#
# 9. **DeBERTa: Decoding-enhanced BERT with Disentangled Attention** (He et al., 2021)
#    - DeBERTa introduces disentangled attention mechanisms and enhances the decoding process, leading to improved performance on various benchmarks.
#
# ### Related Work Suggestions:
# - **Transformers for Vision**: Look into Vision Transformers (ViT) and how the transformer architecture has been adapted for image processing tasks.
# - **Multimodal Transformers**: Research papers that explore transformers in multimodal contexts, such as CLIP (Contrastive Language-Image Pretraining) and DALL-E.
# - **Efficient Transformers**: Papers focusing on reducing the computational cost of transformers, such as Linformer, Performer, and Longformer.
# - **Applications in Other Domains**: Explore how transformers are being applied in fields like bioinformatics (e.g., BioBERT) and code generation (e.g., Codex).
#
# If you want to dive deeper into any specific paper or topic, let me know!

# %% [markdown]
# ### Example 2: Collaboration network analysis

# %%
graph_response2 = enhanced_assistant.ask(
    "What other researchers have worked on transformer architectures? "
    "I want to understand the collaboration network and research groups in this field.",
    user_id="graph_user"
)

print(f"Hybrid Assistant: {graph_response2}")
# Out:
# Hybrid Assistant: To explore the collaboration network and research groups in the field of transformer architectures, you can look into several key researchers and their affiliations. Here are some notable contributors:
#
# 1. **Ashish Vaswani** - One of the authors of the original transformer paper "Attention Is All You Need." He has collaborated with various researchers in the field and is associated with Google Research.
#
# 2. **Jacob Devlin** - The lead author of the BERT paper, which has significantly influenced the use of transformers in natural language processing. He is also affiliated with Google Research.
#
# 3. **Aidan N. Gomez** - Co-author of the original transformer paper and has worked on various projects related to transformers and their applications.
#
# 4. **Thomas Wolf** - Co-founder of Hugging Face, which has played a crucial role in popularizing transformer models through their libraries and tools. He has collaborated with many researchers in the NLP community.
#
# 5. **Yujia Li** - Known for work on various transformer models and has contributed to the development of models like T5.
#
# 6. **Kenton Lee** - Another key figure in the development of BERT and related models, affiliated with Google Research.
#
# To understand the collaboration network, you can use tools like:
#
# - **Semantic Scholar**: This platform provides insights into citation networks and co-authorship graphs.
# - **ResearchGate**: You can explore profiles of researchers and their collaborations.
# - **Google Scholar**: Look for citation patterns and co-authorships in the papers related to transformers.
#
# Additionally, you might want to check out conferences like NeurIPS, ACL, and EMNLP, where many transformer-related papers are presented, as they often highlight collaborations and emerging research groups.
#
# If you need more specific information or resources, feel free to ask!

# %% [markdown]
# ## 🎓 Recap
#
# You just built a real memory system from the ground up. Here's what you accomplished and where to go from here.
#
# ### What you built
# - **Hybrid memory architecture** with vector search (Qdrant) + graph relationships (Neo4j)
# - **Automatic memory extraction** that pulls key facts from conversations
# - **Conflict resolution** that handles contradictions and keeps memories current
# - **Semantic search** that finds relevant info by meaning, not just keywords
#
# ### Why Mem0
#
# Memory is hard to build right. You'd need months to handle fact extraction, conflict resolution, and semantic search properly. Mem0 gives you battle-tested memory that just works.
#
# **What you get:**
# - Smart memory extraction that pulls key facts from conversations automatically
# - Conflict handling when users change their minds or contradict themselves
# - Semantic search that finds relevant stuff by meaning, not just keywords
# - Proven performance: 26% better accuracy, 91% faster responses, 90% fewer tokens (Mem0 research paper)
#
# You can focus on building your app instead of reinventing memory infrastructure.
#
# ### Your deployment options
#
# **Self-hosted (what we built)**
# - Full control over your stack
# - Custom configurations for vector/graph stores
# - Great for learning, prototyping, and specific requirements
#
# **Mem0 Platform**
# - Managed service starting at free tier (10K memories)
# - Enterprise features like analytics and graph memory
# - Simple API, zero infrastructure headaches
# - Ship fast and scale without ops overhead
#
#
# ### What's next
# You now have the foundation for AI that actually remembers and learns. Check out:
#
# - **[Mem0 Platform](https://mem0.dev/dashboard/nir)** for production deployment
# - **[Documentation](https://mem0.dev/docs/nir)** for advanced features and integrations
# - **[Discord Community](https://mem0.dev/discord/nir)** for questions and discussions
#
# You're ready to build AI applications that get smarter with every interaction.
